# %% [markdown]
# # Analyze Genre by Year
#
# We are data analysts at the streaming service `Metpicks`. This company specializes in media from 1990 - 2005. To gain more insight into the average rating and runtime of different media types. we will be analyzing the dataframe `imdb_processed.csv` dataset.
#
# Implement each line of pseudocode in each respective code-block, and then utilize your outputs to answer questions 1 through 4.
#
# If you are stuck on any line of pseudocde, be sure to utilize stackoverflow and google. This will be submitted via google classroom.

# %%
import pandas as pd

# read in your imdb_processed csv into a dataframe
df = pd.read_csv("../data/imdb_processed.csv")

# %%
# print out the first 5 rows of this dataframe
df.head()
# Out:
#    index                                              title  year  \
# 0      0                                    Dinosaur Planet  2003
# 1      1                                  Get Up and Dance!  1994
# 2      2                                              8 Man  1992
# 3      3                       What the #$*! Do We (K)now!?  2004
# 4      4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
#
#              kind                                              genre  rating  \
# 0  tv mini series             ['Documentary', 'Animation', 'Family']     7.7
# 1     video movie                                         ['Family']     8.1
# 2           movie                               ['Action', 'Sci-Fi']     5.5
# 3           movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4           movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
#
#       vote            country                          language  \
# 0    474.0  ['United States']                       ['English']
# 1     18.0  ['United States']                       ['English']
# 2     93.0          ['Japan']                      ['Japanese']
# 3  13432.0  ['United States']  ['English', 'German', 'Spanish']
# 4   2177.0  ['United States']                       ['English']
#
#                                                 cast  \
# 0              ['Christian Slater', 'Scott Sampson']
# 1  ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 2  ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 3  ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4  ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
#
#                                             director                composer  \
# 0                                                NaN                     NaN
# 1                                  ['Steve Purcell']                     NaN
# 2                              ['Yasuhiro Horiuchi']         ['Carole King']
# 3  ['William Arntz', 'Betsy Chasse', 'Mark Vicente']  ['Christopher Franke']
# 4                                    ['Eric Louzil']         ['Bob Mithoff']
#
#                                               writer  runtime
# 0   ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1                                                NaN     83.0
# 2  ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']      NaN
# 3  ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4     ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0

# %%
# print out the length of this dataframe
len(df)
# Out:
# 8451

# %%
# analyze the statistics of this dataframe
df.describe()
# Out:
#              index         year       rating          vote      runtime
# count  8451.000000  8451.000000  8135.000000  8.135000e+03  6798.000000
# mean   4225.000000  1991.626080     6.680000  1.873295e+04    99.984113
# std    2439.737896    15.129001     1.281778  8.957999e+04    65.277725
# min       0.000000  1905.000000     1.500000  5.000000e+00     2.000000
# 25%    2112.500000  1987.000000     6.000000  3.075000e+02    82.000000
# 50%    4225.000000  1998.000000     6.900000  1.531000e+03    95.000000
# 75%    6337.500000  2002.000000     7.600000  6.897500e+03   110.000000
# max    8450.000000  2005.000000     9.600000  2.462087e+06  1620.000000

# %%
# check how many null values your dataframe contains using "info()"
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8451 entries, 0 to 8450
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     8451 non-null   int64
#  1   title     8451 non-null   object
#  2   year      8451 non-null   int64
#  3   kind      8451 non-null   object
#  4   genre     8384 non-null   object
#  5   rating    8135 non-null   float64
#  6   vote      8135 non-null   float64
#  7   country   8152 non-null   object
#  8   language  8052 non-null   object
#  9   cast      8280 non-null   object
#  10  director  7140 non-null   object
#  11  composer  5722 non-null   object
#  12  writer    7204 non-null   object
#  13  runtime   6798 non-null   float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 924.5+ KB

# %%
# drop all null values inplace
clean_df =df.dropna()
print(df.dropna)
# Out:
# <bound method DataFrame.dropna of       index                                              title  year  \
# 0         0                                    Dinosaur Planet  2003
# 1         1                                  Get Up and Dance!  1994
# 2         2                                              8 Man  1992
# 3         3                       What the #$*! Do We (K)now!?  2004
# 4         4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
# ...     ...                                                ...   ...
# 8446   8446                                All Monsters Attack  1969
# 8447   8447                                       Fidel Castro  2005
# 8448   8448                                              Epoch  2001
# 8449   8449                                        The Company  2003
# 8450   8450                                           Predator  1987
#
#                 kind                                              genre  \
# 0     tv mini series             ['Documentary', 'Animation', 'Family']
# 1        video movie                                         ['Family']
# 2              movie                               ['Action', 'Sci-Fi']
# 3              movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...
# 4              movie                     ['Comedy', 'Horror', 'Sci-Fi']
# ...              ...                                                ...
# 8446           movie                 ['Adventure', 'Family', 'Fantasy']
# 8447         episode            ['Documentary', 'Biography', 'History']
# 8448        tv movie                             ['Sci-Fi', 'Thriller']
# 8449           movie                      ['Drama', 'Music', 'Romance']
# 8450           movie      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']
#
#       rating      vote                                         country  \
# 0        7.7     474.0                               ['United States']
# 1        8.1      18.0                               ['United States']
# 2        5.5      93.0                                       ['Japan']
# 3        5.3   13432.0                               ['United States']
# 4        4.5    2177.0                               ['United States']
# ...      ...       ...                                             ...
# 8446     3.9    4384.0                                       ['Japan']
# 8447     6.4      44.0                                             NaN
# 8448     4.9    2376.0                               ['United States']
# 8449     6.3    6501.0  ['United States', 'Germany', 'United Kingdom']
# 8450     7.8  386850.0                     ['United States', 'Mexico']
#
#                                language  \
# 0                           ['English']
# 1                           ['English']
# 2                          ['Japanese']
# 3      ['English', 'German', 'Spanish']
# 4                           ['English']
# ...                                 ...
# 8446                       ['Japanese']
# 8447             ['English', 'Spanish']
# 8448                        ['English']
# 8449                        ['English']
# 8450  ['English', 'Spanish', 'Russian']
#
#                                                    cast  \
# 0                 ['Christian Slater', 'Scott Sampson']
# 1     ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 2     ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 3     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# ...                                                 ...
# 8446  ['Tomonori Yazaki', 'Hideyo Amamoto', 'Sachio ...
# 8447  ['Rena Baskin', 'Fulgencio Batista', 'James Bl...
# 8448  ['David Keith', 'Stephanie Niznik', "Ryan O'Ne...
# 8449  ['Neve Campbell', 'Malcolm McDowell', 'James F...
# 8450  ['Arnold Schwarzenegger', 'Carl Weathers', 'El...
#
#                                                director  \
# 0                                                   NaN
# 1                                     ['Steve Purcell']
# 2                                 ['Yasuhiro Horiuchi']
# 3     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                       ['Eric Louzil']
# ...                                                 ...
# 8446   ['Ishirô Honda', 'Jun Fukuda', 'Kengo Furusawa']
# 8447            ['Adriana Bosch', 'M Pink Christofalo']
# 8448                                      ['Matt Codd']
# 8449                                  ['Robert Altman']
# 8450                                 ['John McTiernan']
#
#                     composer  \
# 0                        NaN
# 1                        NaN
# 2            ['Carole King']
# 3     ['Christopher Franke']
# 4            ['Bob Mithoff']
# ...                      ...
# 8446      ['Kunio Miyauchi']
# 8447        ['Mason Daring']
# 8448      ['Richard McHugh']
# 8449      ['Van Dyke Parks']
# 8450      ['Alan Silvestri']
#
#                                                  writer  runtime
# 0      ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1                                                   NaN     83.0
# 2     ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']      NaN
# 3     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# ...                                                 ...      ...
# 8446                             ["Shin'ichi Sekizawa"]      NaN
# 8447                                  ['Adriana Bosch']      NaN
# 8448  ['Jonathan Raymond', 'Jonathan Raymond', 'Phil...      NaN
# 8449  ['Neve Campbell', 'Barbara Turner', 'Barbara T...      NaN
# 8450                      ['Jim Thomas', 'John Thomas']      NaN
#
# [8451 rows x 14 columns]>

# %%
# print out the length of this dataframe after this drop
len(clean_df)
# Out:
# 4133

# %%
# filter this data to only include rows where years are after 1990
new_data=df[df['year'] >= 1990]
print(new_data)
# Out:
#       index                                              title  year  \
# 0         0                                    Dinosaur Planet  2003
# 1         1                                  Get Up and Dance!  1994
# 2         2                                              8 Man  1992
# 3         3                       What the #$*! Do We (K)now!?  2004
# 4         4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
# ...     ...                                                ...   ...
# 8443   8443                                            Gattaca  1997
# 8445   8445                                Shakespeare in Love  1998
# 8447   8447                                       Fidel Castro  2005
# 8448   8448                                              Epoch  2001
# 8449   8449                                        The Company  2003
#
#                 kind                                              genre  \
# 0     tv mini series             ['Documentary', 'Animation', 'Family']
# 1        video movie                                         ['Family']
# 2              movie                               ['Action', 'Sci-Fi']
# 3              movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...
# 4              movie                     ['Comedy', 'Horror', 'Sci-Fi']
# ...              ...                                                ...
# 8443           movie                    ['Drama', 'Sci-Fi', 'Thriller']
# 8445           movie          ['Comedy', 'Drama', 'History', 'Romance']
# 8447         episode            ['Documentary', 'Biography', 'History']
# 8448        tv movie                             ['Sci-Fi', 'Thriller']
# 8449           movie                      ['Drama', 'Music', 'Romance']
#
#       rating      vote                                         country  \
# 0        7.7     474.0                               ['United States']
# 1        8.1      18.0                               ['United States']
# 2        5.5      93.0                                       ['Japan']
# 3        5.3   13432.0                               ['United States']
# 4        4.5    2177.0                               ['United States']
# ...      ...       ...                                             ...
# 8443     7.8  289781.0                               ['United States']
# 8445     7.1  218921.0             ['United States', 'United Kingdom']
# 8447     6.4      44.0                                             NaN
# 8448     4.9    2376.0                               ['United States']
# 8449     6.3    6501.0  ['United States', 'Germany', 'United Kingdom']
#
#                               language  \
# 0                          ['English']
# 1                          ['English']
# 2                         ['Japanese']
# 3     ['English', 'German', 'Spanish']
# 4                          ['English']
# ...                                ...
# 8443          ['English', 'Esperanto']
# 8445                       ['English']
# 8447            ['English', 'Spanish']
# 8448                       ['English']
# 8449                       ['English']
#
#                                                    cast  \
# 0                 ['Christian Slater', 'Scott Sampson']
# 1     ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 2     ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 3     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# ...                                                 ...
# 8443  ['Ethan Hawke', 'Uma Thurman', 'Gore Vidal', '...
# 8445  ['Geoffrey Rush', 'Tom Wilkinson', "Steven O'D...
# 8447  ['Rena Baskin', 'Fulgencio Batista', 'James Bl...
# 8448  ['David Keith', 'Stephanie Niznik', "Ryan O'Ne...
# 8449  ['Neve Campbell', 'Malcolm McDowell', 'James F...
#
#                                                director  \
# 0                                                   NaN
# 1                                     ['Steve Purcell']
# 2                                 ['Yasuhiro Horiuchi']
# 3     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                       ['Eric Louzil']
# ...                                                 ...
# 8443                                  ['Andrew Niccol']
# 8445                                    ['John Madden']
# 8447            ['Adriana Bosch', 'M Pink Christofalo']
# 8448                                      ['Matt Codd']
# 8449                                  ['Robert Altman']
#
#                     composer  \
# 0                        NaN
# 1                        NaN
# 2            ['Carole King']
# 3     ['Christopher Franke']
# 4            ['Bob Mithoff']
# ...                      ...
# 8443       ['Michael Nyman']
# 8445     ['Stephen Warbeck']
# 8447        ['Mason Daring']
# 8448      ['Richard McHugh']
# 8449      ['Van Dyke Parks']
#
#                                                  writer  runtime
# 0      ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1                                                   NaN     83.0
# 2     ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']      NaN
# 3     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# ...                                                 ...      ...
# 8443                                  ['Andrew Niccol']      NaN
# 8445                    ['Marc Norman', 'Tom Stoppard']      NaN
# 8447                                  ['Adriana Bosch']      NaN
# 8448  ['Jonathan Raymond', 'Jonathan Raymond', 'Phil...      NaN
# 8449  ['Neve Campbell', 'Barbara Turner', 'Barbara T...      NaN
#
# [6012 rows x 14 columns]

# %%
# print out the first 5 rows of this filtered dataframe
new_data.head()
# Out:
#    index                                              title  year  \
# 0      0                                    Dinosaur Planet  2003
# 1      1                                  Get Up and Dance!  1994
# 2      2                                              8 Man  1992
# 3      3                       What the #$*! Do We (K)now!?  2004
# 4      4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
#
#              kind                                              genre  rating  \
# 0  tv mini series             ['Documentary', 'Animation', 'Family']     7.7
# 1     video movie                                         ['Family']     8.1
# 2           movie                               ['Action', 'Sci-Fi']     5.5
# 3           movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4           movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
#
#       vote            country                          language  \
# 0    474.0  ['United States']                       ['English']
# 1     18.0  ['United States']                       ['English']
# 2     93.0          ['Japan']                      ['Japanese']
# 3  13432.0  ['United States']  ['English', 'German', 'Spanish']
# 4   2177.0  ['United States']                       ['English']
#
#                                                 cast  \
# 0              ['Christian Slater', 'Scott Sampson']
# 1  ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 2  ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 3  ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4  ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
#
#                                             director                composer  \
# 0                                                NaN                     NaN
# 1                                  ['Steve Purcell']                     NaN
# 2                              ['Yasuhiro Horiuchi']         ['Carole King']
# 3  ['William Arntz', 'Betsy Chasse', 'Mark Vicente']  ['Christopher Franke']
# 4                                    ['Eric Louzil']         ['Bob Mithoff']
#
#                                               writer  runtime
# 0   ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1                                                NaN     83.0
# 2  ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']      NaN
# 3  ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4     ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0

# %%
# print out the length of this dataframe
len(new_data)
# Out:
# 6012

# %%
# group your dataframe into seperate groups according to "kind"
new_data.sort_values("kind")
# Out:
#       index                                              title  year  \
# 5600   5600                                 Girl in Gold Boots  1999
# 3967   3967                     Truman Capote: The Tiny Terror  1997
# 1175   1175                                Faithful unto Death  1998
# 5144   5144                            Well Schooled in Murder  2002
# 2874   2874                       The Four Brothers Under Fire  1991
# ...     ...                                                ...   ...
# 1413   1413                          Bloodfist V: Human Target  1994
# 1414   1414                 Batman Beyond: Return of the Joker  2000
# 4267   4267  Michael W. Smith - Live in Concert: A 20 Year ...  2004
# 4256   4256                       Batman & Mr. Freeze: SubZero  1998
# 5720   5720                            Heart: Alive in Seattle  2003
#
#              kind                                              genre  rating  \
# 5600      episode                               ['Comedy', 'Sci-Fi']     6.9
# 3967      episode                       ['Documentary', 'Biography']     8.5
# 1175      episode                      ['Crime', 'Drama', 'Mystery']     7.5
# 5144      episode           ['Crime', 'Drama', 'Mystery', 'Romance']     7.3
# 2874      episode                                      ['Animation']     NaN
# ...           ...                                                ...     ...
# 1413  video movie                                         ['Action']     5.3
# 1414  video movie  ['Animation', 'Action', 'Crime', 'Sci-Fi', 'Th...     7.8
# 4267  video movie                                          ['Music']     NaN
# 4256  video movie  ['Animation', 'Action', 'Crime', 'Drama', 'Sci...     7.2
# 5720  video movie                                          ['Music']     8.6
#
#          vote             country     language  \
# 5600    626.0   ['United States']  ['English']
# 3967    115.0                 NaN          NaN
# 1175    912.0  ['United Kingdom']  ['English']
# 5144    463.0  ['United Kingdom']  ['English']
# 2874      NaN                 NaN          NaN
# ...       ...                 ...          ...
# 1413    412.0   ['United States']  ['English']
# 1414  25404.0   ['United States']  ['English']
# 4267      NaN   ['United States']  ['English']
# 4256  15041.0   ['United States']  ['English']
# 5720     91.0   ['United States']  ['English']
#
#                                                    cast  \
# 5600  ['Kevin Murphy', 'Michael J. Nelson', 'Mary Jo...
# 3967                                                NaN
# 1175  ['John Nettles', 'Daniel Casey', 'Jane Wymark'...
# 5144  ['John Sessions', 'Lisa Stevenson', 'Curtis Wo...
# 2874                                                NaN
# ...                                                 ...
# 1413  ['Don Wilson', 'Denice Duff', 'Steve James', '...
# 1414  ['Will Friedle', 'Kevin Conroy', 'Mark Hamill'...
# 4267                               ['Michael W. Smith']
# 4256  ['Kevin Conroy', 'Michael Ansara', 'Loren Lest...
# 5720  ['Ann Wilson', 'Nancy Wilson', 'Scott Olson', ...
#
#                             director                       composer  \
# 5600                ['Kevin Murphy']                            NaN
# 3967                             NaN                            NaN
# 1175                  ['Baz Taylor']                 ['Jim Parker']
# 5144                ['Robert Young']            ['Robert Lockhart']
# 2874                ['Osamu Dezaki']             ['Hiroyuki Namba']
# ...                              ...                            ...
# 1413                  ['Jeff Yonis']  ['David Wurst', 'Eric Wurst']
# 1414                   ['Curt Geda']          ['Kristopher Carter']
# 4267  ['Ken Conrad', 'Carl Diebold']                            NaN
# 4256               ['Boyd Kirkland']         ['Michael McCuistion']
# 5720                ['Dave Diomedi']                            NaN
#
#                                                  writer  runtime
# 5600  ['Joel Hodgson', 'Michael J. Nelson', 'Paul Ch...     98.0
# 3967                                                NaN     92.0
# 1175           ['Douglas Watkinson', 'Caroline Graham']     24.0
# 5144                ['Elizabeth George', 'Simon Block']     93.0
# 2874                                                NaN    106.0
# ...                                                 ...      ...
# 1413                     ['Rob Kerchner', 'Jeff Yonis']     40.0
# 1414         ['Bob Kane', 'Paul Dini', 'Glen Murakami']     96.0
# 4267                                                NaN     88.0
# 4256       ['Randy Rogel', 'Boyd Kirkland', 'Bob Kane']     89.0
# 5720                                                NaN     86.0
#
# [6012 rows x 14 columns]

# %%
# print out all your media groups
media_groups=list(new_data["kind"].tolist())
print(media_groups)
# Out:
# ['tv mini series', 'video movie', 'movie', 'movie', 'movie', 'episode', 'video movie', 'tv movie', 'tv movie', 'episode', 'tv movie', 'episode', 'tv series', 'video movie', 'tv mini series', 'video movie', 'tv mini series', 'movie', 'video movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'video movie', 'tv series', 'movie', 'movie', 'tv mini series', 'movie', 'tv series', 'video movie', 'video movie', 'tv movie', 'movie', 'movie', 'video movie', 'movie', 'video movie', 'movie', 'video movie', 'movie', 'video movie', 'movie', 'movie', 'video movie', 'movie', 'tv series', 'movie', 'movie', 'video movie', 'video movie', 'tv mini series', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'tv series', 'movie', 'tv movie', 'movie', 'tv movie', 'movie', 'video movie', 'video movie', 'tv series', 'movie', 'video movie', 'movie', 'tv movie', 'episode', 'movie', 'movie', 'video movie', 'episode', 'movie', 'video movie', 'movie', 'tv series', 'episode', 'video movie', 'movie', 'tv series', 'video movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'video movie', 'movie', 'movie', 'movie', 'video movie', 'video movie', 'tv movie', 'tv movie', 'video movie', 'video movie', 'movie', 'tv movie', 'movie', 'tv movie', 'episode', 'movie', 'episode', 'movie', 'video movie', 'movie', 'movie', 'tv series', 'movie', 'video movie', 'movie', 'movie', 'movie', 'video movie', 'video movie', 'movie', 'tv movie', 'movie', 'video movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'tv mini series', 'video movie', 'tv series', 'movie', 'episode', 'episode', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'episode', 'tv series', 'video movie', 'tv series', 'movie', 'movie', 'movie', 'episode', 'movie', 'tv movie', 'tv mini series', 'movie', 'tv movie', 'movie', 'video movie', 'episode', 'movie', 'video movie', 'movie', 'video movie', 'video movie', 'tv series', 'movie', 'tv movie', 'tv series', 'video movie', 'video movie', 'movie', 'episode', 'movie', 'movie', 'video movie', 'tv series', 'movie', 'movie', 'movie', 'video movie', 'episode', 'tv series', 'video movie', 'movie', 'tv movie', 'video movie', 'video movie', 'movie', 'tv series', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'tv movie', 'tv mini series', 'episode', 'tv movie', 'movie', 'video movie', 'video movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'tv movie', 'movie', 'tv movie', 'video movie', 'episode', 'movie', 'tv movie', 'tv series', 'tv series', 'movie', 'tv mini series', 'tv mini series', 'tv series', 'tv movie', 'movie', 'tv series', 'movie', 'movie', 'video movie', 'movie', 'tv movie', 'movie', 'movie', 'tv series', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'episode', 'video movie', 'movie', 'movie', 'tv movie', 'episode', 'video movie', 'video movie', 'tv movie', 'episode', 'tv mini series', 'movie', 'video movie', 'episode', 'tv series', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'tv movie', 'movie', 'video movie', 'movie', 'tv series', 'movie', 'episode', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'video movie', 'movie', 'tv series', 'tv movie', 'video movie', 'video movie', 'video movie', 'movie', 'movie', 'tv series', 'tv movie', 'movie', 'episode', 'tv mini series', 'tv movie', 'episode', 'movie', 'movie', 'movie', 'movie', 'episode', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv series', 'video movie', 'movie', 'tv movie', 'movie', 'video movie', 'video movie', 'tv series', 'tv mini series', 'video movie', 'movie', 'video movie', 'episode', 'movie', 'video movie', 'tv mini series', 'movie', 'movie', 'video movie', 'tv movie', 'movie', 'movie', 'tv series', 'movie', 'movie', 'episode', 'tv movie', 'tv movie', 'tv  ...

# %%
# calculate the mean rating of each group
means = new_data.groupby("kind")["rating"].mean()
means.plot.bar()

# plot this dataframe of mean ratings as a bar-graph
# Out:
# <AxesSubplot: xlabel='kind'>

# %%
# calculate the mean runtime of each group
means = new_data.groupby("kind")["runtime"].mean()
means.plot.bar()

# plot this dataframe of mean runtime as a bar-graph
# Out:
# <AxesSubplot: xlabel='kind'>

# %% [markdown]
# ## Q1
#
# Which media type has the highest mean ranking? TV Short

# %% [markdown]
# ## Q2
#
# Which media type has the lowest mean ranking? Movie or TV Movie

# %% [markdown]
# ## Q3
#
# Which media type has the highest mean runtime? Video Game

# %% [markdown]
# ## Q4
#
#
# Which media type has the lowest mean runtime? TV short

# %% [markdown]
# ## Challenge
#
# Transform your column `genre` into multiple columns, where `1` indicates presnce of this genre.
#
# Read more about this setup here: https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/
#
# Utilize stackoverflow and the internet to solve this challenge
